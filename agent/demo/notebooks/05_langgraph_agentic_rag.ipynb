# %% [markdown]
# # 05 LangGraph Agentic RAG
# Run the classify/rewrite/retrieve/rerank/grade/answer workflow.

# %%
from agent_workshop_demo.langgraph_workflow import build_default_workflow
workflow = build_default_workflow()
response = workflow.run('我们 S3 文档同步流程是怎么设计的？')
response['answer'], response['trace']['evidence_grading']
