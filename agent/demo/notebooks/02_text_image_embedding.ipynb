# %% [markdown]
# # 02 Text + Image Embedding
# Demonstrate deterministic text embeddings and image-vector placeholders.

# %%
from agent_workshop_demo.embedding import dense_vector, image_vector
text_vec = dense_vector('S3 sync pipeline Milvus retrieval')
img_vec = image_vector('S3 sync flow diagram')
len(text_vec), len(img_vec)
