# %% [markdown]
# # 01 Ingestion: Local Docs + Mock S3
# Load workshop documents and generate kb/dedup records.

# %%
from pathlib import Path
from agent_workshop_demo.ingestion import ingest_demo_sources
result = ingest_demo_sources(Path('../sample_data/local_docs'), Path('../sample_data/mock_s3'))
len(result.kb_chunks), len(result.dedup_signatures)
