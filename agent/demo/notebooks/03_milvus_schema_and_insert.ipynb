# %% [markdown]
# # 03 Milvus Schema and Insert
# Inspect collection definitions before creating them with pymilvus.

# %%
from agent_workshop_demo.schema.collections import KB_CHUNKS_COLLECTION
KB_CHUNKS_COLLECTION['collection_name'], [field['name'] for field in KB_CHUNKS_COLLECTION['fields']]
